# %%
import pandas as pd
import re
import string
import emoji
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("/content/product_reviews.csv")

# %%
df.head()
# Out:
#    Review_ID                                 Review_Text
# 0          1  Great Product! Loved it 😊. Worth the price
# 1          2   Terrible quailty... broke after 2 days!!👎
# 2          3           Meh, it's okay. Nothing special.🙄
# 3          4   Absolutely fantastic! Highly recommend!!!
# 4          5      Worst purchase ever. Do Not buy this.😔

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review_ID    5 non-null      int64
#  1   Review_Text  5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
df.shape
# Out:
# (5, 2)

# %%
def clean_text_regex(text):
    text = str(text)

    text = text.lower()

    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)

    text = re.sub(r'\d+', '', text)

    text = emoji.replace_emoji(text, replace="")

    stop_words = set(stopwords.words('english'))
    text = " ".join(word for word in text.split() if word not in stop_words)

    return text

# %%
df['Cleaned_Text'] = df['Review_Text'].apply(clean_text_regex)
df
# Out:
#    Review_ID                                 Review_Text  \
# 0          1  Great Product! Loved it 😊. Worth the price
# 1          2   Terrible quailty... broke after 2 days!!👎
# 2          3           Meh, it's okay. Nothing special.🙄
# 3          4   Absolutely fantastic! Highly recommend!!!
# 4          5      Worst purchase ever. Do Not buy this.😔
#
#                             Cleaned_Text
# 0        great product loved worth price
# 1            terrible quailty broke days
# 2               meh okay nothing special
# 3  absolutely fantastic highly recommend
# 4                worst purchase ever buy

# %%
file_path = "cleaned_reviews.csv"
df.to_csv(file_path, index=False)

print(f"Cleaned data saved to {file_path}")
# Out:
# Cleaned data saved to cleaned_reviews.csv
