# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\COLLEGE WORK\SEM 5\Machine Learning\Exploratory Data Analysis\AB_NYC_2019.csv\AB_NYC_2019.csv")

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df = df.drop(['last_review','reviews_per_month'],axis=1)

# %%
df = df.drop(['latitude','longitude'],axis=1)

# %%
df.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
sns.barplot(x='neighbourhood_group',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='price'>

# %%
avg_predered_price = df.groupby(['neighbourhood_group','room_type'], as_index=False)['price'].mean()

# %%
avg_predered_price = df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()

# %%
avg_predered_price
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     127.645503     66.788344    58.610169
# Brooklyn                  178.362609     76.510619    50.527845
# Manhattan                 249.238211    116.805594    88.977083
# Queens                    147.050573     71.776855    69.020202
# Staten Island             173.846591     62.292553    57.444444

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.barplot(x='neighbourhood_group',y='price',hue='room_type',data=df)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='price'>

# %%
avg_predered_price.plot.bar()
# Out:
# <AxesSubplot:xlabel='neighbourhood_group'>

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
# no_of_active_host = df.groupby(['neighbourhood_group'])['host_id'].count().sort_values()

no_of_host_per_location = df.groupby('neighbourhood_group',as_index=False)['host_id'].count().sort_values(['host_id'], ascending=False)

# %%
no_of_host_per_location
# Out:
#   neighbourhood_group  host_id
# 2           Manhattan    21643
# 1            Brooklyn    20089
# 3              Queens     5664
# 0               Bronx     1089
# 4       Staten Island      373

# %%
df[df['minimum_nights']==1].sort_values(['price'])
# Out:
#              id                                               name    host_id  \
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 21700  17437106               Couch in Harlem Harvey Refugees only   33511962
# 32810  25839759  Gigantic Sunny Room in Park Slope-Private Back...  167570251
# ...         ...                                                ...        ...
# 44034  33998396                   3000 sq ft daylight photo studio    3750764
# 45666  34895693                               Gem of east Flatbush  262534951
# 42523  33007610                70' Luxury MotorYacht on the Hudson    7407743
# 29662  22779726          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 4377    2953058                                      Film Location    1177497
#
# ...

# %%
highest_rent = df.groupby(['neighbourhood_group'],as_index=False)['price'].max().sort_values(['price'],ascending=True)
highest_rent
# Out:
#   neighbourhood_group  price
# 0               Bronx   2500
# 4       Staten Island   5000
# 1            Brooklyn  10000
# 2           Manhattan  10000
# 3              Queens  10000

# %%
sns.lineplot(x=highest_rent['neighbourhood_group'],y=highest_rent['price'])
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='price'>

# %%
lowest_rent = df.groupby(['neighbourhood_group'],as_index=False)['price'].min().sort_values(['price'],ascending=True)
lowest_rent
# Out:
#   neighbourhood_group  price
# 0               Bronx      0
# 1            Brooklyn      0
# 2           Manhattan      0
# 3              Queens     10
# 4       Staten Island     13

# %%
merge_price = pd.merge(highest_rent,lowest_rent,on=['neighbourhood_group'])
merge_price
# Out:
#   neighbourhood_group  price_x  price_y
# 0               Bronx     2500        0
# 1       Staten Island     5000       13
# 2            Brooklyn    10000        0
# 3           Manhattan    10000        0
# 4              Queens    10000       10

# %%
merge_price = merge_price.rename(columns={'price_x':'Maximum_price','price_y':'Minimum_price'})

# %%
merge_price
# Out:
#   neighbourhood_group  Maximum_price  Minimum_price
# 0               Bronx           2500              0
# 1       Staten Island           5000             13
# 2            Brooklyn          10000              0
# 3           Manhattan          10000              0
# 4              Queens          10000             10

# %%
sns.barplot(x=merge_price['neighbourhood_group'],y=merge_price['Maximum_price'])
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='Maximum_price'>

# %%
merge_price.plot(x='neighbourhood_group',y=['Maximum_price','Minimum_price'],kind='bar')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group'>

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
popolar_review = df.groupby(['host_id','host_name'],as_index=False)['number_of_reviews'].sum().sort_values(['number_of_reviews'],ascending=False)

# %%
popolar_availability =  df.groupby(['host_id','host_name'],as_index=False)['availability_365'].mean().sort_values(['availability_365'],ascending=True)

# %%
merge_df = pd.merge(popolar_review,popolar_availability,on=['host_id','host_name']).sort_values(['availability_365','number_of_reviews'],ascending=[True,False]).rename(columns={'number_of_reviews':'Number of reviews','availability_365':'Availability in a year'})
merge_df
# Out:
#          host_id        host_name  Number of reviews  Availability in a year
# 12      22959695  Gurpreet  Singh               1157                     0.0
# 41      99392252          Michael                732                     0.0
# 47     121391142          Deloris                693                     0.0
# 122       792159            Wanda                480                     0.0
# 125     37818581            Sofia                479                     0.0
# ...          ...              ...                ...                     ...
# 37133   37360127              Mel                  0                   365.0
# 37137   37424221           Trevor                  0                   365.0
# 37225   35741633             Chen                  0                   365.0
# 37248   40834217              Jay                  0                   365.0
# 37263   40733012           Victor                  0                   365.0
#
# [37425 rows x 4 columns]

# %%
merge_df.head()
# Out:
#        host_id        host_name  Number of reviews  Availability in a year
# 12    22959695  Gurpreet  Singh               1157                     0.0
# 41    99392252          Michael                732                     0.0
# 47   121391142          Deloris                693                     0.0
# 122     792159            Wanda                480                     0.0
# 125   37818581            Sofia                479                     0.0

# %%
plt.figure(figsize=(10,6),dpi=200)
merge_df.plot(x='Number of reviews',y='Availability in a year',kind='scatter',xlim=(100,1000),ylim=(10,380))
# Out:
# <AxesSubplot:xlabel='Number of reviews', ylabel='Availability in a year'>

# %% [markdown]
# # By Shantanu Houzwala
# Answering following Questions:
# Find the total count of each room type
#
# Which are the top 25 most used words in listing names?
#
# Find top 10 hosts with most listings

# %%
df[df['room_type']=='Private room'].count()
# Out:
# id                                22306
# name                              22306
# host_id                           22306
# host_name                         22306
# neighbourhood_group               22306
# neighbourhood                     22306
# room_type                         22306
# price                             22306
# minimum_nights                    22306
# number_of_reviews                 22306
# calculated_host_listings_count    22306
# availability_365                  22306
# dtype: int64

# %%
room_count = df['room_type'].value_counts()
room_count
# Out:
# Entire home/apt    25393
# Private room       22306
# Shared room         1159
# Name: room_type, dtype: int64

# %%
sns.barplot(x=room_count.index,y=room_count)
# Out:
# <AxesSubplot:ylabel='room_type'>

# %%
top_10_host = df.groupby(['host_id','host_name','calculated_host_listings_count'], as_index=False)['calculated_host_listings_count'].sum().sort_values(['calculated_host_listings_count'],ascending=False)
top_10_host
# Out:
#          host_id       host_name  calculated_host_listings_count
# 34615  219517861    Sonder (NYC)                          106929
# 29379  107434423      Blueground                           53824
# 19557   30283594            Kara                           14641
# 31050  137358866          Kazuya                           10609
# 14426   16098958  Jeremy & Laura                            9216
# ...          ...             ...                             ...
# 13347   13538150         Mariana                               1
# 13346   13535952       Nastassia                               1
# 13345   13533446          Daniel                               1
# 13344   13532838             Nik                               1
# 37424  274321313             Kat                               1
#
# [37425 rows x 3 columns]

# %%
top_10_host.head(10)
# Out:
#          host_id          host_name  calculated_host_listings_count
# 34615  219517861       Sonder (NYC)                          106929
# 29379  107434423         Blueground                           53824
# 19557   30283594               Kara                           14641
# 31050  137358866             Kazuya                           10609
# 14426   16098958     Jeremy & Laura                            9216
# 12796   12243051             Sonder                            9216
# 25637   61391963  Corporate Housing                            8281
# 17079   22541573                Ken                            7569
# 33837  200380610            Pranjal                            4225
# 9725     7503643               Vida                            2704

# %%
plt.figure(figsize=(6,4),dpi=150)
plt.ylim((0,350))
sns.boxplot(x='neighbourhood_group',y='availability_365',data=df)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='availability_365'>

# %%
len(df['host_id'].value_counts())
# Out:
# 37425

# %%
df['host_id'].value_counts()
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 26676357       1
# 43311385       1
# 544621         1
# 21573063       1
# 68119814       1
# Name: host_id, Length: 37425, dtype: int64

# %%
top_10_host = df.groupby(['host_id','host_name'],as_index=False)['host_id'].value_counts().sort_values(['count'],ascending=False)
top_10_host
# Out:
#          host_id     host_name  count
# 34615  219517861  Sonder (NYC)    327
# 29379  107434423    Blueground    232
# 19557   30283594          Kara    121
# 31050  137358866        Kazuya    103
# 12796   12243051        Sonder     96
# ...          ...           ...    ...
# 13347   13538150       Mariana      1
# 13346   13535952     Nastassia      1
# 13345   13533446        Daniel      1
# 13344   13532838           Nik      1
# 37424  274321313           Kat      1
#
# [37425 rows x 3 columns]

# %%
top_10_host.head(10)
# Out:
#          host_id          host_name  count
# 34615  219517861       Sonder (NYC)    327
# 29379  107434423         Blueground    232
# 19557   30283594               Kara    121
# 31050  137358866             Kazuya    103
# 12796   12243051             Sonder     96
# 14426   16098958     Jeremy & Laura     96
# 25637   61391963  Corporate Housing     91
# 17079   22541573                Ken     87
# 33837  200380610            Pranjal     65
# 3041     1475015               Mike     52

# %%
plt.xticks(rotation=90)
sns.barplot(x='host_name',y='count',data=top_10_host.head(10))
# Out:
# <AxesSubplot:xlabel='host_name', ylabel='count'>

# %%
df[df['price']<50]
# Out:
#              id                                             name    host_id  \
# 28         9518     SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM      31374
# 36        11452                      Clean and Quiet in Brooklyn       7355
# 39        12048              LowerEastSide apt share shortterm 1       7549
# 58        15338                  Room in Greenpoint Loft w/ Roof      32169
# 149       34760  Sunny Room in Old Historical Brooklyn Townhouse     149929
# ...         ...                                              ...        ...
# 48871  36475746    A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
# 48877  36479230           Studio sized room with beautiful light   65767720
# 48878  36479723                                    Room for rest   41326856
# 48882  36482231                        Bushwick _ Myrtle-Wyckoff   66058896
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
#
# ...

# %%
df['price'].describe()
# Out:
# count    48858.000000
# mean       152.740309
# std        240.232386
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
plt.xlim((0,400))
sns.boxplot(df['price'])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
new_df = df[df['price']>50]
new_df
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# ...         ...                                                ...        ...
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
final_df = new_df[new_df['price']>=80]

# %%
final_df
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# ...         ...                                                ...        ...
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
final_df['price'].describe()
# Out:
# count    33046.000000
# mean       199.180566
# std        280.303687
# min         80.000000
# 25%        104.000000
# 50%        150.000000
# 75%        207.750000
# max      10000.000000
# Name: price, dtype: float64

# %%
host_df = final_df.groupby(['host_id','host_name'],as_index=False)['price'].sum().sort_values(['price'],ascending=False)

# %%
host_df.head(3)
# Out:
#          host_id     host_name  price
# 24891  219517861  Sonder (NYC)  82795
# 21449  107434423    Blueground  70331
# 23170  156158778         Sally  37097

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.xticks(rotation=45)
sns.barplot(x='host_name',y='price',data=host_df.head(3))
# Out:
# <AxesSubplot:xlabel='host_name', ylabel='price'>

# %%
nights_df = df.groupby(['neighbourhood_group'],as_index=False)['minimum_nights'].sum().sort_values(['minimum_nights'],ascending=False)

# %%
nights_df
# Out:
#   neighbourhood_group  minimum_nights
# 2           Manhattan          184792
# 1            Brooklyn          121693
# 3              Queens           29356
# 0               Bronx            4971
# 4       Staten Island            1802

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.xticks(rotation=45)
sns.barplot(x='neighbourhood_group',y='minimum_nights',data=nights_df)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='minimum_nights'>

# %%
nights_per_room = df.groupby(['room_type'],as_index=False)['minimum_nights'].sum().sort_values(['minimum_nights'],ascending=False)

# %%
nights_per_room
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt          215081
# 1     Private room          120023
# 2      Shared room            7510

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.xticks(rotation=45)
sns.barplot(x='room_type',y='minimum_nights',data=nights_per_room)
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='minimum_nights'>

# %%
top_listing_neighbour = df.groupby(['neighbourhood'],as_index=False)['neighbourhood'].value_counts().sort_values(['count'],ascending=False).reset_index()

# %%
top_listing_neighbour.head(10)
# Out:
#    index       neighbourhood  count
# 0    214        Williamsburg   3917
# 1     13  Bedford-Stuyvesant   3713
# 2     94              Harlem   2655
# 3     28            Bushwick   2462
# 4    202     Upper West Side   1969
# 5     95      Hell's Kitchen   1954
# 6     64        East Village   1852
# 7    201     Upper East Side   1797
# 8     51       Crown Heights   1563
# 9    127             Midtown   1545

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.xticks(rotation=45)
sns.barplot(x='neighbourhood',y='count',data=top_listing_neighbour.head(10))
# Out:
# <AxesSubplot:xlabel='neighbourhood', ylabel='count'>

# %% [markdown]
# # Conclusion
# Manhattan is the most focused place in New York for hosts to do their business
#
# Customers pay highest amount in Brooklyn,Queens and Manhattan that is 10,000 and lowest amount is 10$.
#
# For the three types of room type (i.e. Entire home, Shared room, & Private room) average price of entire home is around $157, for shared room is around 60, and for private room is around 75.
#
# 'Entire home/apt' room type has the highest number of listing of 52% and ‘Shared Room’ is the least listed room type at only 2.4% in total.
#
# People stay for longer duration of time in Private rooms in Brooklyn and Manhattan.
#
# Words such as ‘bedroom’, ‘cozy’, ‘private’, ‘apartment’ and ‘spacious’ are used more frequently than words such as ‘park’, ‘near’, ‘village’ and ‘heart’. Count of listing by top 10 hosts is almost 2.5%(1270 listings) of the whole dataset. Top three host base on their turnover are Sonder(nyc),Red awning, Henry and best host is Sonder(nyc) More customer preferred Manhattan location for night stay then Brooklyn *63.2% customer spend night in Entire home and 1.6% spend night in Shared room
